# %% [markdown]
# <a href="https://www.kaggle.com/code/agropixel26/test-colab-coder-final?scriptVersionId=292785794" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
print("Hello from Colab to Kaggle!")
# Out:
# Hello from Colab to Kaggle!
