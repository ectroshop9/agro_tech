# %% [markdown]
# <a href="https://colab.research.google.com/github/ectroshop9/agro_tech/blob/main/Test_Colab_Coder_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from Colab to Kaggle!")
